# %% [markdown]
# ## here we're going to talk about descriptive statistics which' kind of statistics in general
# ## another kind of general statistics is inferentail statistics used in sampling and surveys arround globe
#    ## infereintial statistics:  a powerful way to draw conclusions about whole groups of people based on data from a small sample.
#
# ## There are two types of Descriptive Statistics:
#
# 1. The measure of central tendency
# 2. Measure of variability
#
# ![image.png](attachment:image.png)
#
#
# ### Measure of Central Tendency
#
# The measure of central tendency is a single value that attempts to describe the whole set of data. There are three main features of central tendency:
#
# 1. Mean
# 2. Median
# 2. a) Median Low
# 2. b) Median High
# 3. Mode
#
# ![image-2.png](attachment:image-2.png)
#
# ### Mean:
#
# It is the sum of observations divided by the total number of observations. It is also defined as average which is the sum divided by count.
#
# ![image-3.png](attachment:image-3.png)
#
# The mean() function returns the mean or average of the data passed in its arguments. If the passed argument is empty, StatisticsError is raised.

# %%
import statistics 

lis= [13,25,24,65,76,4,5,3,87,55]
#for printing mean of above elements in the list 
print(f"here your list of numbers: {lis} \nand mean of all these numbers is: {statistics.mean(lis)}")
# Out:
# here your list of numbers: [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# and mean of all these numbers is: 35.7

# %% [markdown]
# ### Median:
#
# It is the middle value of the data set. It splits the data into two halves. If the number of elements in the data set is odd then the center element is the median and if it is even then the median would be the average of two central elements. it first sorts the data and then performs the median operation.
#
#
# ### there is another functionality in python to create fractional-rational numbers using liberary fraction and it method fraction:
# class fractions.Fraction(numerator=0, denominator=1) these're bydefault values : This requires that numerator and denominator are instances of numbers. Rational and a fraction instance with value = (numerator/denominator) is returned. A zerodivision error is raised if denominator = 0.

# %%
#statistics's median method can work on various types of data-sequnces like float, fractions and integers , -ves etc
# first here we import the Fraction method from fractions lib
from fractions import Fraction as fr
from statistics import median

# as we lready has lis
print("Data-1: ",lis) #[even numbers of element]

lis2=(2,3,4,3,5,9,5,12) # tuples of +ve integer [even numbers of elements]
print("Data-2: ",lis2)

lis3 = (2.5,1.8,4.5,4.7,5.9) # tuples of floting numbers [odd numbers of elements]
print("Data-3: ", lis3)

lis4 = (fr(1, 2), fr(44, 12),fr(10, 3), fr(2, 3))
# tuples of fractional numbers [here even numbers of fractional elements]
print("Data-4: ", lis4)

lis5 = (-5,-1,-9,-2,-4,6) # tuples of -ve numbers 
print("Data-5: ",lis5)

# now printing median of all the made -up data above 
print("median of Data-1: ",median(lis))
print("median of Data-2: ",median(lis2))
print("median of Data-3: ",median(lis3))
print("median of Data-4: ",median(lis4))
print("median of Data-5: ",median(lis5))
# Out:
# Data-1:  [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# Data-2:  (2, 3, 4, 3, 5, 9, 5, 12)
# Data-3:  (2.5, 1.8, 4.5, 4.7, 5.9)
# Data-4:  (Fraction(1, 2), Fraction(11, 3), Fraction(10, 3), Fraction(2, 3))
# Data-5:  (-5, -1, -9, -2, -4, 6)
# median of Data-1:  24.5
# median of Data-2:  4.5
# median of Data-3:  4.5
# median of Data-4:  2
# median of Data-5:  -3.0

# %% [markdown]
# ### Median Low:
#
# The median_low() function returns the median of data in case of odd number of elements, but in case of even number of elements, returns the lower of two middle elements. If the passed argument is empty, StatisticsError is raised
#
# ### Median High:
# The median_high() function returns the median of data in case of odd number of elements, but in case of even number of elements, returns the higher of two middle elements. If passed argument is empty, StatisticsError is raised.

# %%
from statistics import median_high as mdh
from statistics import median_low as mdl
print("Data-1: ",lis)
print("Data-2: ",lis2)
print("Data-3: ",lis3)
print("Data-4: ",lis4)
print("Data-5: ",lis5)
print("====================================")
# now printing median-high of all the made -up data above 
print("median of Data-1: ",mdh(lis))
print("median of Data-2: ",mdh(lis2))
print("median of Data-3: ",mdh(lis3))
print("median of Data-4: ",mdh(lis4))
print("median of Data-5: ",mdh(lis5))

print("====================================")
# now printing median-low of all the made -up data above 
print("median of Data-1: ",mdl(lis))
print("median of Data-2: ",mdl(lis2))
print("median of Data-3: ",mdl(lis3))
print("median of Data-4: ",mdl(lis4))
print("median of Data-5: ",mdl(lis5))
# Out:
# Data-1:  [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# Data-2:  (2, 3, 4, 3, 5, 9, 5, 12)
# Data-3:  (2.5, 1.8, 4.5, 4.7, 5.9)
# Data-4:  (Fraction(1, 2), Fraction(11, 3), Fraction(10, 3), Fraction(2, 3))
# Data-5:  (-5, -1, -9, -2, -4, 6)
# ...
# median of Data-1:  25
# median of Data-2:  5
# median of Data-3:  4.5
# median of Data-4:  10/3
# median of Data-5:  -2
# ...
# median of Data-1:  24
# median of Data-2:  4
# median of Data-3:  4.5
# median of Data-4:  2/3
# median of Data-5:  -4

# %% [markdown]
# ### Mode
# It is the value that has the highest frequency in the given data set. The data set may have no mode if the frequency of all data points is the same. Also, we can have more than one mode if we encounter two or more data points having the same frequency.
#
# The mode() function returns the number with the maximum number of occurrences. If the passed argument is empty, StatisticsError is raised.

# %%
# Importing the statistics module 
from statistics import mode 
 
# Importing fractions module as fr 
# Enables to calculate harmonic_mean of a 
# set in Fraction 
from fractions import Fraction as fr 
 
# tuple of positive integer numbers 
data1 = (2, 3, 3, 4, 5, 5, 5, 5, 6, 6, 6, 7) 
 
# tuple of a set of floating point values 
data2 = (2.4, 1.3, 1.3, 1.3, 2.4, 4.6) 
 
# tuple of a set of fractional numbers 
data3 = (fr(1, 2), fr(1, 2), fr(10, 3), fr(2, 3)) 
 
# tuple of a set of negative integers 
data4 = (-1, -2, -2, -2, -7, -7, -9) 
 
# tuple of strings 
data5 = ("red", "blue", "black", "blue", "black", "black", "brown") 
 
 
# Printing out the mode of the above data-sets 
print("Mode of data-1 is %", mode(data1))
print("Mode of data-2 is % s", mode(data2)) 
print("Mode of data-3 is % s", mode(data3)) 
print("Mode of data-4 is % s", mode(data4)) 
print("Mode of data-5 is % s", mode(data5))
# Out:
# Mode of data-1 is % 5
# Mode of data-2 is % s 1.3
# Mode of data-3 is % s 1/2
# Mode of data-4 is % s -2
# Mode of data-5 is % s black

# %% [markdown]
# ## Measure of Variability
# Till now, we have studied the measure of central tendency but this alone is not sufficient to describe the data. To overcome this we need the measure of variability. The measure of variability is known as the spread of data or how well our data is distributed. The most common variability measures are:
#
# 1. Range
# 2. Variance
# 3. Standard deviation
#
#
# ![image.png](attachment:image.png)
#
# ### Range:
# The difference between the largest and smallest data point in our data set is known as the range. The range is directly proportional to the spread of data which means the bigger the range, the more the spread of data and vice versa.
#
# - formulation:
# Range = Largest data value – smallest data value
#
# We can calculate the maximum and minimum values using the max() and min() methods respectively.

# %%
print("here is the DATA:", lis)

#finding out maximum ele in list 
max_ele = max(lis)
# finding out minimum element in the list 
min_ele = min(lis)

Range= max_ele - min_ele

print(f"maimum element of list: {max_ele} \nminimum element of list: {min_ele} \nand range of the list: {Range}")
# Out:
# here is the DATA: [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# maimum element of list: 87
# minimum element of list: 3
# and range of the list: 84

# %% [markdown]
# ### Variance
# It is defined as an average squared deviation from the mean. It is calculated by finding the difference between every data point and the average which is also known as the mean, squaring them, adding all of them, and then dividing by the number of data points present in our data set.
#
#
# ![image.png](attachment:image.png)
#
# where N = number of terms
#
# u = Mean
#
# The statistics module provides the variance() method that does all the maths behind the scene. If the passed argument is empty, StatisticsError is raised.

# %%
from statistics import variance as vr
print("Data-1: ",lis)
print("Data-2: ",lis2)
print("Data-3: ",lis3)
print("Data-4: ",lis4)
print("Data-5: ",lis5)
print("====================================")
# now printing Varience of all the made -up data above 
print("varience of Data-1: ",vr(lis))
print("varience of Data-2: ",vr(lis2))
print("Varience of Data-3: ",vr(lis3))
print("Varience of Data-4: ",vr(lis4))
print("Varience of Data-5: ",vr(lis5))
# Out:
# Data-1:  [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# Data-2:  (2, 3, 4, 3, 5, 9, 5, 12)
# Data-3:  (2.5, 1.8, 4.5, 4.7, 5.9)
# Data-4:  (Fraction(1, 2), Fraction(11, 3), Fraction(10, 3), Fraction(2, 3))
# Data-5:  (-5, -1, -9, -2, -4, 6)
# ...
# varience of Data-1:  1030.0111111111112
# varience of Data-2:  11.696428571428571
# Varience of Data-3:  2.8420000000000005
# Varience of Data-4:  1235/432
# Varience of Data-5:  25.1

# %% [markdown]
# # Standard Deviation
#
# It is defined as the square root of the variance. It is calculated by finding the Mean, then subtracting each number from the Mean which is also known as the average, and squaring the result. Adding all the values and then dividing by the no of terms followed by the square root.
#
# ![image.png](attachment:image.png)
#
# where N = number of terms
#
# u = Mean
#
# The stdev() method of the statistics module returns the standard deviation of the data. If the passed argument is empty, StatisticsError is raised.

# %%
from statistics import stdev as stdv
print("Data-1: ",lis)
print("Data-2: ",lis2)
print("Data-3: ",lis3)
print("Data-4: ",lis4)
print("Data-5: ",lis5)
print("====================================")
# now printing Varience of all the made -up data above 
print("Standard Deviation of Data-1: ",stdv(lis))
print("Standard Deviation of Data-2: ",stdv(lis2))
print("Standard Deviation of Data-3: ",stdv(lis3))
print("Standard Deviation of Data-4: ",stdv(lis4))
print("Standard Deviation of Data-5: ",stdv(lis5))
# Out:
# Data-1:  [13, 25, 24, 65, 76, 4, 5, 3, 87, 55]
# Data-2:  (2, 3, 4, 3, 5, 9, 5, 12)
# Data-3:  (2.5, 1.8, 4.5, 4.7, 5.9)
# Data-4:  (Fraction(1, 2), Fraction(11, 3), Fraction(10, 3), Fraction(2, 3))
# Data-5:  (-5, -1, -9, -2, -4, 6)
# ...
# Standard Deviation of Data-1:  32.09378617600471
# Standard Deviation of Data-2:  3.420004177106889
# Standard Deviation of Data-3:  1.6858232410309215
# Standard Deviation of Data-4:  1.6907975326148001
# Standard Deviation of Data-5:  5.0099900199501395
